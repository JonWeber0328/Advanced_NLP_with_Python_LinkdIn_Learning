# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('data/X_train.csv')
X_test = pd.read_csv('data/X_test.csv')
y_train = pd.read_csv('data/y_train.csv')
y_test = pd.read_csv('data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0  ['selected', 'stay', '1', '250', 'top', 'briti...
# 1  ['love', 'daddy', 'make', 'scream', 'pleasure'...
# 2  ['dare', 'stupid', 'wont', 'tell', 'anything',...
# 3         ['ok', 'ill', 'send', 'ltdecimalgt', 'ok']
# 4  ['ha', 'ha', 'cool', 'cool', 'chikku', 'chikku...

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'selected': 6360,
#  'stay': 6838,
#  '250': 412,
#  'top': 7384,
#  'british': 1599,
#  'hotels': 3700,
#  'nothing': 5135,
#  'holiday': 3650,
#  'worth': 8024,
#  '350': 496,
#  'claim': 1935,
#  'call': 1694,
#  'london': 4442,
#  '02072069400': 10,
#  'bx': 1671,
#  '526': 608,
#  'sw73ss': 7030,
#  'love': 4482,
#  'daddy': 2266,
#  'make': 4586,
#  'scream': 6318,
#  'pleasure': 5580,
#  'going': 3329,
#  'slap': 6579,
#  'ass': 1179,
#  'dick': 2444,
#  'dare': 2287,
#  'stupid': 6936,
#  'wont': 7990,
#  'tell': 7148,
#  'anything': 1083,
#  'hear': 3543,
#  'talk': 7087,
#  'ok': 5232,
#  'ill': 3821,
#  'send': 6372,
#  'ltdecimalgt': 4511,
#  'ha': 3456,
#  'cool': 2120,
#  'chikku': 1889,
#  'chikkudb': 1891,
#  'huh': 3747,
#  'means': 4671,
#  'computational': 2056,
#  'science': 6305,
#  'like': 4360,
#  'dat': 2298,
#  'one': 5258,
#  'push': 5850,
#  'wifehow': 7922,
#  'knew': 4200,
#  'time': 7300,
#  'murder': 4936,
#  'exactly': 2838,
#  'got': 3361,
#  'new': 5041,
#  'year': 8143,
#  'cos': 2136,
#  'yetunde': 8170,
#  'said': 6235,
#  'wanted': 7793,
#  'surprise': 7020,
#  'didnt': 2447,
#  'see': 6347,
#  'money': 4851,
#  'returned': 6112,
#  'mid': 4748,
#  'january': 4019,
#  'ltgt': 4514,
#  'day': 2311,
#  'return': 6111,
#  'period': 5479,
#  'ended': 2738,
#  'cooked': 2117,
#  'rather': 5920,
#  'nice': 5055,
#  'salmon': 6245,
#  'la': 4231,
#  'whats': 7891,
#  'want': 7792,
#  'come': 2022,
#  'online': 5265,
#  'babe': 1258,
#  'miiiiiiissssssssss': 4753,
#  'need': 5010,
#  'crave': 2183,
#  'geeee': 3244,
#  'im': 3824,
#  'sad': 6228,
#  'without': 7957,
#  'yar': 8134,
#  'lor': 4458,
#  'keep': 4142,
#  'raining': 5893,
#  'non': 5111,
#  'stop': 6878,
#  'wan': 7787,
#  'go': 3311,
#  'elsewhere': 2720,
#  'uncles': 7547,
#  'atlanta': 1191,
#  'wish': 7948,
#  'guys': 3451,
#  'great': 3397,
#  'semester': 6369,
#  'enough': 2756,
#  'pick': 5525,
#  'bread': 1572,
#  'milk': 4757,
#  'give': 3293,
#  'back': 1268,
#  'get': 3265,
#  'home': 3656,
#  'still': 6866,
#  'havent': 3526,
#  'urself': 7623,
#  'jacket': 4004,
#  'ah': 954,
#  'word': 7998,
#  'checkmate': 1860,
#  'chess': 1876,
#  'comes': 2025,
#  'persian': 5485,
#  'phrase': 5521,
#  'shah': 6419,
#  'maat': 4552,
#  'king': 4176,
#  'dead': 2325,
#  'goodmorning': 3346,
#  'good': 3340,
#  'hello': 3565,
#  'news': 5045,
#  'job': 4058,
#  'making': 4590,
#  'wait': 7764,
#  'fifth': 2970,
#  'week': 7849,
#  'yeah': 8141,
#  'woozles': 7996,
#  'weasels': 7831,
#  'exeter': 2849,
#  'chikkuil': 1892,
#  'aftr': 938,
#  'mins': 4775,
#  'total': 7398,
#  'disappointment': 2490,
#  'texted': 7186,
#  'craziest': 2185,
#  'shit': 6453,
#  'text': 7182,
#  'way': 7820,
#  'cup': 2233,
#  'work': 8002,
#  'bus': 1654,
#  'spook': 6771,
#  'mob': 4823,
#  'halloween': 3477,
#  'collection': 2011,
#  'logo': 4433,
#  'pic': 5524,
#  'message': 4724,
#  'plus': 5591,
#  'free': 3125,
#  'eerie': 2691,
#  'tone': 7364,
#  'txt': 7504,
#  'card': 1751,
#  '8007': 710,
#  'zed': 8220,
#  '08701417012150p': 64,
#  'per': 5468,
#  'logopic': 4436,
#  'super': 6996,
#  'dagood': 2269,
#  'replacement': 6057,
#  'murali': 4935,
#  'also': 1017,
#  'watch': 7809,
#  'pm': 5594,
#  'show': 6487,
#  'plans': 5565,
#  'family': 2912,
#  'set': 6394,
#  'stone': 6875,
#  'jokin': 4075,
#  'oni': 5262,
#  'lar': 4263,
#  'ìï': 8233,
#  'busy': 1658,
#  'wun': 8060,
#  'disturb': 2508,
#  'oh': 5226,
#  'diet': 2453,
#  'flew': 3033,
#  'window': 7932,
#  'argh': 1138,
#  'fuck': 3174,
#  'nobody': 5093,
#  'town': 7406,
#  'happiness': 3504,
#  'updatenow': 7595,
#  'xmas': 8114,
#  'offer': 5211,
#  'latest': 4277,
#  'motorola': 4885,
#  'sonyericsson': 6684,
#  'nokia': 5104,
#  'bluetooth': 1486,
#  'double': 2570,
#  '1000': 251,
#  'orange': 5297,
#  'mobileupd8': 4829,
#  '08000839402': 41,
#  'call2optoutf4q': 1697,
#  'ya': 8127,
#  'taking': 7084,
#  'ure': 7612,
#  'practical': 5690,
#  'lessons': 4329,
#  'start': 6824,
#  'june': 4103,
#  'bears': 1353,
#  'nick': 5058,
#  'tom': 7355,
#  'pete': 5495,
#  'fact': 2892,
#  'types': 7517,
#  'try': 7464,
#  'gay': 3229,
#  'chat': 1846,
#  'photo': 5517,
#  'upload': 7599,
#  '08718730666': 139,
#  '10pmin': 267,
#  'texts': 7191,
#  '08712460324': 99,
#  'important': 3839,
#  'badrith': 1275,
#  'chennaii': 1872,
#  'surely': 7015,
#  'usno': 7637,
#  'competition': 2044,
#  'theory': 7225,
#  'argument': 1141,
#  'wins': 7942,
#  'situation': 6556,
#  'loses': 4464,
#  'person': 5486,
#  'dont': 2558,
#  'argue': 1139,
#  'ur': 7611,
#  'friends': 3154,
#  'kick': 4162,
#  'amp': 1037,
#  'say': 6287,
#  'always': 1021,
#  'correct': 2130,
#  'thats': 7209,
#  'late': 4271,
#  'well': 7865,
#  'night': 5063,
#  'tomorrow': 7361,
#  'iam': 3783,
#  'sleep': 6581,
#  'change': 1826,
#  'windows': 7933,
#  'logoff': 4434,
#  'sound': 6709,
#  'aight': 966,
#  'ask': 1171,
#  'roommates': 6175,
#  'think': 7244,
#  'use': 7627,
#  'ni8': 5052,
#  'honeybee': 3666,
#  'sweetest': 7041,
#  'world': 8009,
#  'god': 3318,
#  'laughed': 4280,
#  'waitu': 7770,
#  'havnt': 3530,
#  'met': 4739,
#  'reading': 5939,
#  'msg': 4902,
#  'moral': 4869,
#  'even': 2808,
#  'crack': 2175,
#  'jokes': 4073,
#  'gmgngegn': 3307,
#  'studies': 6926,
#  'alone': 1008,
#  'anyones': 1080,
#  'help': 3571,
#  'cant': 1740,
#  'study': 6928,
#  'afternoon': 936,
#  'glorious': 3303,
#  'anniversary': 1058,
#  'sweet': 7040,
#  'hope': 3677,
#  'finds': 2996,
#  'happy': 3505,
#  'content': 2099,
#  'prey': 5739,
#  'teasing': 7137,
#  'kiss': 4180,
#  'across': 876,
#  'sea': 6329,
#  'coaxing': 1989,
#  'images': 3826,
#  'fond': 3066,
#  'souveniers': 6718,
#  'cougarpen': 2146,
#  'put': 5854,
#  'party': 5415,
#  'days': 2316,
#  'lightly': 4358,
#  'draw': 2590,
#  'custom': 2245,
#  'checkboxes': 1856,
#  'know': 4203,
#  'hardcore': 3507,
#  'superb': 6997,
#  'thought': 7263,
#  'grateful': 3390,
#  'everything': 2824,
#  'opportunity': 5284,
#  'happier': 3501,
#  'today': 7337,
#  'entry': 2765,
#  'wkly': 7966,
#  'comp': 2037,
#  'win': 7929,
#  'fa': 2885,
#  'final': 2990,
#  'tkts': 7322,
#  '21st': 400,
#  'may': 4659,
#  '2005': 387,
#  '87121': 764,
#  'receive': 5967,
#  'questionstd': 5871,
#  'ratetcs': 5919,
#  'apply': 1107,
#  '08452810075over18s': 58,
#  'sorryin': 6697,
#  'meeting': 4686,
#  'later': 4275,
#  'tee': 7140,
#  'hee': 3557,
#  'lecture': 4311,
#  'cheery': 1866,
#  'bye': 1675,
#  'pls': 5585,
#  'forget': 3086,
#  'lost': 4467,
#  'rebooting': 5961,
#  'sorry': 6696,
#  'man': 4596,
#  'stash': 6832,
#  'ran': 5907,
#  'dry': 2627,
#  'last': 4268,
#  'sunday': 6989,
#  'thatd': 7204,
#  'pretty': 5734,
#  'much': 4919,
#  'best': 1403,
#  'case': 1776,
#  'scenario': 6299,
#  'chillin': 1903,
#  'bowl': 1534,
#  'plan': 5560,
#  'prospects': 5812,
#  'missing': 4794,
#  'lazy': 4292,
#  'bleak': 1463,
#  'hmmm': 3634,
#  'filled': 2982,
#  'mapquest': 4613,
#  'something': 6669,
#  'look': 4448,
#  'usf': 7632,
#  'dogwood': 2543,
#  'drive': 2608,
#  'haha': 3463,
#  'yup': 8213,
#  'hopefully': 3681,
#  'lose': 4462,
#  'kg': 4158,
#  'mon': 4848,
#  'hip': 3617,
#  'hop': 3676,
#  'orchard': 5300,
#  'weigh': 7855,
#  'wat': 7808,
#  'really': 5951,
#  'tonight': 7371,
#  'messagethanks': 4734,
#  'using': 7635,
#  'auction': 1207,
#  'subscription': 6954,
#  'service': 6391,
#  '18': 344,
#  '150pmsgrcvd': 320,
#  'skip': 6571,
#  'unsubscribe': 7588,
#  'customercare': 2247,
#  '08718726270': 128,
#  'type': 7516,
#  'forgot': 3090,
#  'lect': 4310,
#  'saw': 6286,
#  'pouch': 5671,
#  'believe': 1386,
#  'many': 4611,
#  'things': 7243,
#  'morning': 4874,
#  'beautiful': 1355,
#  'library': 4340,
#  'toopray': 7381,
#  'meremove': 4719,
#  'teeth': 7141,
#  'painful': 5369,
#  'maintaining': 4584,
#  'stuff': 6931,
#  'omg': 5253,
#  'could': 2149,
#  'snow': 6645,
#  'tonite': 7373,
#  'fujitsu': 3181,
#  'series': 6387,
#  'lifebook': 4348,
#  'mums': 4933,
#  'repent': 6055,
#  'anytime': 1086,
#  'tariffs': 7102,
#  'camera': 1725,
#  'phones': 5515,
#  '2stoptxt': 464,
#  'tcs': 7123,
#  'hmmbad': 3633,
#  'newshype': 5048,
#  'park': 5404,
#  'plaza': 5576,
#  '700': 676,
#  'studio': 6927,
#  'takenonly': 7081,
#  'left': 4312,
#  'bedrm900': 1364,
#  'studying': 6929,
#  'next': 5050,
#  'weekend': 7850,
#  'sez': 6409,
#  'hows': 3717,
#  'de': 2324,
#  'arab': 1129,
#  'boy': 1553,
#  'evry1': 2833,
#  'eshxxxxxxxxxxx': 2787,
#  'shola': 6464,
#  'please': 5577,
#  'college': 2013,
#  'medicine': 4679,
#  'visit': 7718,
#  'academic': 850,
#  'department': 2397,
#  'secretary': 6339,
#  'current': 2238,
#  'transfer': 7421,
#  'someone': 6665,
#  'check': 1855,
#  'sagamu': 6233,
#  'thing': 7241,
#  'lautech': 4285,
#  'vital': 7722,
#  'completes': 2051,
#  'medical': 4678,
#  'education': 2684,
#  'nigeria': 5061,
#  'less': 4327,
#  'expensive': 2860,
#  'unless': 7576,
#  'getting': 3273,
#  'citizen': 1931,
#  'rates': 5918,
#  'zealand': 8218,
#  'head': 3533,
#  'dey': 2433,
#  'swell': 7045,
#  'thanks': 7197,
#  'sister': 6550,
#  'belongs': 1392,
#  'pray': 5701,
#  'herwho': 3595,
#  'fated': 2926,
#  'shoranur': 6471,
#  'train': 7415,
#  'incident': 3853,
#  'lets': 4331,
#  'hold': 3646,
#  'hands': 3485,
#  'together': 7345,
#  'fuelled': 3180,
#  'concern': 2063,
#  'prior': 5753,
#  'grief': 3409,
#  'pain': 5368,
#  'join': 4066,
#  'dis': 2487,
#  'chain': 1818,
#  'pass': 5418,
#  'violence': 7710,
#  'women': 7983,
#  'bad': 1272,
#  'avoid': 1237,
#  'hiwhat': 3626,
#  'match': 4638,
#  'honey': 3665,
#  'find': 2994,
#  'sell': 6365,
#  'predicte': 5708,
#  'times': 7303,
#  'used': 7628,
#  'reply': 6061,
#  'monday': 4849,
#  'car': 1750,
#  'keys': 4156,
#  'purse': 5849,
#  'course': 2160,
#  'guess': 3438,
#  'gods': 3321,
#  'right': 6130,
#  'fills': 2984,
#  'complete': 2048,
#  'calm': 1721,
#  'reassurance': 5958,
#  'life': 4346,
#  'spend': 6746,
#  'lifetime': 4351,
#  'meaningless': 4670,
#  'moments': 4846,
#  'spent': 6748,
#  'petey': 5496,
#  'whereare': 7901,
#  'friendsare': 3155,
#  'thekingshead': 7217,
#  'canlove': 1737,
#  'nic': 5054,
#  'trip': 7446,
#  'remember': 6032,
#  'must': 4944,
#  'decide': 2349,
#  'easter': 2668,
#  'film': 2985,
#  '2day': 433,
#  'da': 2260,
#  '6pm': 669,
#  'review': 6119,
#  'fantastic': 2918,
#  'ngage': 5051,
#  'game': 3212,
#  'deck': 2354,
#  'club': 1975,
#  'wwwcnupdatescomnewsletter': 8068,
#  'alerts': 988,
#  'promise': 5796,
#  'take': 7078,
#  'care': 1754,
#  'princess': 5748,
#  'run': 6211,
#  'pics': 5529,
#  'chance': 1824,
#  'ttyl': 7474,
#  'dear': 2332,
#  'voucher': 7739,
#  'holder': 3647,
#  'weeks': 7853,
#  'pc': 5450,
#  'httpwwwetlpcoukexpressoffer': 3733,
#  'tscs': 7469,
#  'apply2': 1108,
#  '80062': 709,
#  'apps': 1120,
#  'class': 1943,
#  'varaya': 7664,
#  'elaya': 2711,
#  'finished': 3004,
#  'yet': 8168,
#  'solve': 6660,
#  'found': 3106,
#  'murdered': 4937,
#  '1his': 359,
#  'wife': 7921,
#  'called': 1708,
#  'police': 5623,
#  '2police': 461,
#  'questioned': 5869,
#  'everyone': 2820,
#  '3wife': 530,
#  'siri': 6545,
#  'sleeping': 6583,
#  'took': 7377,
#  'place': 5554,
#  '4cook': 572,
#  'cooking': 2119,
#  '5gardener': 618,
#  'picking': 5527,
#  'vegetables': 7674,
#  '6housemaid': 666,
#  'went': 7874,
#  'post': 5660,
#  'office': 5215,
#  '7children': 697,
#  'play': 5567,
#  '8neighbour': 797,
#  'marriage': 4626,
#  'arrested': 1156,
#  'murderer': 4938,
#  'immediately': 3834,
#  'whos': 7911,
#  'reason': 5955,
#  'brilliant': 1590,
#  'us': 7624,
#  'mr': 4897,
#  'sheffield': 6435,
#  'wanna': 7790,
#  'okay': 5233,
#  'youre': 8195,
#  'boss': 1522,
#  'nanny': 4977,
#  'raise': 5894,
#  'hack': 3459,
#  'backdoor': 1270,
#  '121': 284,
#  'rooms': 6176,
#  'fraction': 3114,
#  'cost': 2138,
#  'neo69': 5025,
#  '09050280520': 159,
#  'subscribe': 6949,
#  '25p': 415,
#  'dps': 2585,
#  'bcm': 1342,
#  'box': 1536,
#  '8027': 716,
#  'ldn': 4294,
#  'wc1n3xx': 7824,
#  'tel': 7144,
#  'shall': 6423,
#  'steyn': 6860,
#  'wicket': 7916,
#  'might': 4752,
#  'kerala': 4150,
#  'daysso': 2318,
#  'prepared': 5720,
#  'leave': 4307,
#  'finalise': 2991,
#  'travel': 7430,
#  'visitneed': 7720,
#  'finish': 3002,
#  'urgent': 7614,
#  'works': 8008,
#  'earlier': 2656,
#  'putting': 5855,
#  'firesare': 3011,
#  'around': 1151,
#  'actually': 888,
#  'lol': 4439,
#  'company': 2040,
#  'pa': 5358,
#  'else': 2719,
#  'self': 6362,
#  'nothin': 5134,
#  'mind': 4766,
#  'buy': 1663,
#  'hanger': 3490,
#  'laptop': 4262,
#  'heavy': 3556,
#  '150': 306,
#  'discount': 2497,
#  'voucherstext': 7741,
#  'yes': 8153,
#  '85023': 750,
#  'nowsavamobmember': 5155,
#  'offers': 5213,
#  'mobile': 4825,
#  'cs': 2213,
#  '08717898035': 123,
#  '300': 476,
#  'sub': 6942,
#  '16': 339,
#  'remove': 6042,
#  '100': 250,
#  'music': 4942,
#  'gift': 3279,
#  'vouchers': 7740,
#  'every': 2814,
#  'starting': 6828,
#  '87066': 761,
#  'wwwidewcom': 8074,
#  'skillgame': 6567,
#  '1winaweek': 378,
#  'age16': 942,
#  '150ppermesssubscription': 324,
#  'sent': 6381,
#  'phone': 5511,
#  'display': 2505,
#  'number': 5170,
#  'hey': 3601,
#  'ive': 3993,
#  'booked': 1507,
#  'sun': 6987,
#  'liao': 4336,
#  'theyre': 7238,
#  'female': 2956,
#  'howre': 3716,
#  'throwing': 7276,
#  'deciding': 2351,
#  'address': 898,
#  'applespairsall': 1105,
#  'malarky': 4592,
#  'pig': 5538,
#  'leh': 4318,
#  'dad': 2265,
#  'wake': 7771,
#  '10': 249,
#  'smth': 6634,
#  'eat': 2670,
#  'lunch': 4527,
#  'plz': 5593,
#  'sir': 6544,
#  'id': 3798,
#  'kind': 4173,
#  'get4an18th': 3266,
#  'loves': 4492,
#  'problem': 5768,
#  'let': 4330,
#  'gonna': 3339,
#  'predicting': 5709,
#  'inch': 3851,
#  'accumulation': 867,
#  'staff': 6804,
#  'placement': 5556,
#  'training': 7417,
#  'amrita': 1039,
#  'thk': 7253,
#  'juz': 4110,
#  'accordin': 861,
#  'discussed': 2500,
#  'yest': 8166,
#  'except': 2842,
#  'kb': 4139,
#  'theres': 7231,
#  'nt': 5162,
#  'lesson': 4328,
#  'attend': 1199,
#  'sat': 6269,
#  'ipod': 3947,
#  'mp3': 4896,
#  'player': 5569,
#  '400': 536,
#  'proze': 5817,
#  'guaranteed': 3431,
#  '83355': 739,
#  'norcorp': 5121,
#  'ltdå': 4512,
#  '150mtmsgrcvd18': 311,
#  'download': 2578,
#  'clear': 1951,
#  'movies': 4893,
#  'dvd': 2649,
#  'copies': 2122,
#  'watching': 7810,
#  'cartoon': 1775,
#  'listening': 4398,
#  'eve': 2805,
#  'temple': 7159,
#  'church': 1927,
#  'elaine': 2709,
#  'todays': 7341,
#  'guoyang': 3447,
#  'told': 7352,
#  'ringtone': 6139,
#  'changed': 1827,
#  '25': 411,
#  'credits': 2194,
#  'club4mobilescom': 1977,
#  'choose': 1915,
#  '87070': 762,
#  '150pwk': 331,
#  'club4': 1976,
#  'po': 5596,
#  'box1146': 1537,
#  'mk45': 4810,
#  '2wt': 471,
#  'speak': 6730,
#  'feel': 2946,
#  'words': 7999,
#  'better': 1411,
#  'silence': 6520,
#  'gud': 3433,
#  'mrng': 4898,
#  'six': 6559,
#  'chances': 1825,
#  'cash': 1777,
#  '20000': 384,
#  'pounds': 5674,
#  'csh11': 2214,
#  '87575': 768,
#  '150pday': 313,
#  '6days': 664,
#  'tsandcs': 7468,
#  'hl': 3628,
#  'info': 3879,
#  'ready': 5940,
#  'long': 4445,
#  'omw': 5254,
#  'officially': 5220,
#  'philosophical': 5507,
#  'hole': 3649,
#  'saved': 6283,
#  'worried': 8015,
#  'body': 1495,
#  'repairs': 6053,
#  'quite': 5876,
#  'sure': 7014,
#  'shouldnt': 6482,
#  'worry': 8018,
#  'slow': 6600,
#  'first': 3013,
#  'tests': 7178,
#  'guide': 3443,
#  'ovulation': 5346,
#  'relax': 6020,
#  'youve': 8202,
#  'followin': 3064,
#  'afternon': 935,
#  'maybe': 4661,
#  'interviews': 3924,
#  'miss': 4791,
#  'passionate': 5423,
#  'attending': 1200,
#  'talks': 7092,
#  'valuable': 7658,
#  'affectionate': 926,
#  'loveable': 4483,
#  'eternal': 2796,
#  'noble': 5092,
#  'truthful': 7463,
#  'intimate': 3927,
#  'natural': 4989,
#  'enamous': 2736,
#  'valentines': 7656,
#  'advance': 915,
#  'weighed': 7856,
#  'weight': 7857,
#  'woohoo': 7994,
#  'angry': 1052,
#  'dr': 2586,
#  'awarded': 1243,
#  '2000': 383,
#  'prize': 5760,
#  '09058094454': 165,
#  'land': 4250,
#  'line': 4375,
#  '3030': 480,
#  'valid': 7657,
#  '12hrs': 292,
#  'eatin': 2672,
#  'meet': 4683,
#  'sexy': 6407,
#  'date': 2300,
#  'flirt': 3040,
#  '10p': 266,
#  'name': 4969,
#  'age': 941,
#  'eg': 2695,
#  'sam': 6248,
#  'recdthirtyeight': 5964,
#  'pence': 5462,
#  'explicit': 2870,
#  'sex': 6403,
#  '30': 475,
#  'secs': 6342,
#  'ring': 6136,
#  '02073162414': 11,
#  'costs': 2141,
#  '20pmin': 394,
#  'gsex': 3426,
#  'pobox': 5598,
#  '2667': 418,
#  'wc1n': 7823,
#  '3xx': 533,
#  'hospital': 3693,
#  'wif': 7920,
#  'frens': 3143,
#  'lei': 4320,
#  'replied': 6059,
#  'mail': 4577,
#  'management': 4600,
#  'bank': 1297,
#  'alsoor': 1018,
#  'wednesday': 7844,
#  'drastic': 2589,
#  'waiti': 7766,
#  'min': 4763,
#  'nite': 5079,
#  'trying': 7465,
#  'contact': 2095,
#  'shows': 6493,
#  '800': 707,
#  '09050000460': 151,
#  'j89': 4001,
#  'box245c2150pm': 1540,
#  'monthly': 4863,
#  'password': 5426,
#  'wap': 7796,
#  'mobsicom': 4831,
#  '391784': 506,
#  'kate': 4133,
#  'jackson': 4006,
#  'rec': 5962,
#  'center': 1811,
#  '7ish': 698,
#  'erutupalam': 2782,
#  'thandiyachu': 7193,
#  'uk': 7531,
#  'charged': 1837,
#  '5month': 625,
#  'confirm': 2074,
#  'replying': 6063,
#  'never': 5037,
#  'blame': 1457,
#  'experience': 2861,
#  'essential': 2792,
#  'blessings': 1469,
#  'mm': 4812,
#  'kanji': 4124,
#  'matthew': 4653,
#  '09063440451': 193,
#  'landline': 4252,
#  'complimentary': 2053,
#  '4lux': 583,
#  'tenerife': 7163,
#  'await': 1239,
#  'ppm150': 5685,
#  'sae': 6229,
#  'box334': 1542,
#  'sk38xh': 6563,
#  'prevent': 5735,
#  'dehydration': 2376,
#  'giving': 3296,
#  'fluids': 3050,
#  'house': 3706,
#  '8am': 791,
#  'available': 1225,
#  'though': 7262,
#  'walk': 7775,
#  'julianaland': 4099,
#  'oblivious': 5198,
#  'constantly': 2094,
#  'ear': 2655,
#  'whatever': 7890,
#  'upsetits': 7606,
#  'listen': 4396,
#  'upset': 7605,
#  'surprised': 7021,
#  'mad': 4561,
#  'nah': 4964,
#  'goin': 3327,
#  'wrks': 8046,
#  'wot': 8026,
#  'bout': 1531,
#  'pub': 5829,
#  'strong': 6914,
#  'arms': 1148,
#  'alfie': 991,
#  'moons': 4868,
#  'children': 1898,
#  'song': 6680,
#  'm8s': 4549,
#  'charity': 1839,
#  'nokias': 5108,
#  'poly': 5626,
#  'polys': 5633,
#  '08701417012': 63,
#  'profit': 5787,
#  'evry': 2832,
#  'emotion': 2732,
#  'dsnt': 2629,
#  'hav': 3524,
#  'wordsevry': 8000,
#  'prayrs': 5704,
#  'smiled': 6617,
#  'wit': 7954,
#  'uothrwise': 7590,
#  'drop': 2614,
#  'tear': 7135,
#  'lik': 4359,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8241 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.818 / Accuracy: 0.976
